# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/Shareddrives/ETICA/tweets_contradictorios.csv')

# %%
df
# Out:
#                                                 tweet
# 0   Crees que Irene Montero está MALTRATANDO INJUS...
# 1   Descubro accidentalmente que Javier Ortega Smi...
# 2               Pedro Sanchez es genial hijos de puta
# 3   Abascal, Ortega Smith, Espinosa, Monssterio y ...
# 4   "Nazi en el Mediterráneo" con Ortega Smith me ...
# 5   Por qué a la derecha no le gusta el Papa y por...
# 6   Muy necesaria las vacunas a los niños, ya que ...
# 7   Muy bien, Pedro. Un día menos para que te hech...
# 8   Lo de lograr la inmunidad de rebaño lo van con...
# 9   El acoso que sufrió @PabloIglesias, @IreneMont...
# 10  Soy yo el unico que piensa que Irene Montero n...
# 11             Buena propuesta de ley, no hagáis más.
# 12  A Isabel Díaz Ayuso, después de esto, no le qu...
# 13                                         Ciudadanos
# 14  Si tan lista es Ayuso, ¿por qué no deduce con ...
# 15  La definición de tener más cara que espalda. S...
# 16  Buen discurso de Ayuso, pero mis dos Cacatuas ...
# 17  Ayuso se gasta más de 17 millones en toros y a...
# 18  Algunos por lo menos pagan el chalé, no como E...
# 19  Monasterio pide a Ayuso quitar las subvencione...
# 20  Mejor votarte a ti, que pides Netflix en catal...
# 21  Estoy de acuerdo, mejor votar a la extrema izq...
# 22  al trabajador que se parte el lomo para pagars...
# 23  Con odio viven Santiago Abascal, Javier Ortega...
# 24  Dice Rocío Monasterio que jamás había conocido...
# 25  ¿Pablo Casado ha comparado la segregación raci...
# 26  Seguro que te van a votar a ti que te embolsas...
# 27  SEÑOR FRA-CASADO, @pablocasado UN DIA SE LO VA...
# 28  @PP desde luego para hacernos reír sois los me...
# 29            @marianorajoy gracias por todo, chorizo
# 30  Gracias por destruir a la derecha de este país...
# 31  Mariano Rajoy no sabia nada del dinero negro q...
# 32  Ayuso es PP. Que no te engañen. Fue la niña mi...
# 33  ¿En qué universidad cursó usted la carrera? ¿E...
# 34       Ya no pintas nada fachita. Te deseo lo mejor
# 35  Cristina cifuentes cayó por unas cremas de Ola...

# %%
# !pip install transformers
import transformers
from transformers import pipeline
pipe = pipeline("text-classification", model="Newtral/xlm-r-finetuned-toxic-political-tweets-es")
# Out:
# Collecting transformers
#   Downloading transformers-4.13.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 5.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 46.4 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 43.8 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 47.9 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 428 kB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.13.0
# Downloading:   0%|          | 0.00/753 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.04G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/421 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/8.66M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
for idx,row in df.iterrows():
  value = pipe(row.tweet, return_all_scores=True)[0]
  print(row.tweet)
  print("Toxic value: " , value[0]['score'])
  print("Very toxic value: ", value[1]['score'])
# Out:
# Crees que Irene Montero está MALTRATANDO INJUSTAMENTE a la mayoria de los hombres???
# Toxic value:  0.9964796900749207
# Very toxic value:  0.947788655757904
# Descubro accidentalmente que Javier Ortega Smith me tiene bloqueada. Se ve que algunos de mis tweets les hacen pupita a los bozaleros, vacuneros y disidencia controlada de Vox. A ningún traidor le gusta que le echen en cara su falta de moralidad
# Toxic value:  0.9942271709442139
# Very toxic value:  0.9959847927093506
# Pedro Sanchez es genial hijos de puta
# Toxic value:  0.7625391483306885
# Very toxic value:  0.27000150084495544
# Abascal, Ortega Smith, Espinosa, Monssterio y Olona, todos delincuentes y/o hijos de delincuentes que engañan al pueblo con propaganda NAZI haciendoles creer que representan a la España que madruga
# Toxic value:  0.9911064505577087
# Very toxic value:  0.9976933598518372
# "Nazi en el Mediterráneo" con Ortega Smith me pone los pelos de punta...
# Toxic value:  0.011204921640455723
# Very toxic value:  0.0018374152714386582
# Por qué a la derecha no le gusta el Papa y por qué calificaron su encuentro con Yolanda Díaz como reunión entre comunistas
# Toxic value:  0.9657853841781616
# Very toxic value:  0.012006615288555622
# Muy necesaria las vacunas a los niños, ya que han muerto 20 en toda España por covid.
# Toxic value:  0.08666453510522842
# Very toxic value:  0.0009766885777935386
# Muy bien, Pedro. Un día menos para que te hechemos, usurpador.
# Toxic value:  0.9905153512954712
# Very toxic value:  0.47176679968833923
# Lo de lograr la inmunidad de rebaño lo van consiguiendo, porque somos una sociedad de borregos que pese a ver sus derechos más fundamentales pisoteados por estos políticos que nos gobiernan, no hemos salido a la calle a gritar basta ya
# Toxic value:  0.9886646270751953
# Very toxic value:  0.05767717957496643
# El acoso que sufrió @PabloIglesias, @IreneMontero y sus hijos, frente a su casa, también es condenable.
# Toxic value:  0.015507746487855911
# Very toxic value:  0.0016316459514200687
# Soy yo el unico que piensa que Irene Montero necesita ayuda psiquiatrica?
# Toxic value:  0.10519038140773773
# Very toxic value:  0.0014271512627601624
# Buena propuesta de ley, no hagáis más.
# Toxic value:  0.010827843099832535
# Very toxic value:  0.0018111788667738438
# A Isabel Díaz Ayuso, después de esto, no le queda otra opción que dimitir. Qué menos.
# Toxic value:  0.944199800491333
# Very toxic value:  0.01091187633574009
# Ciudadanos
# Toxic value:  0.5303067564964294
# Very toxic value:  0.26983726024627686
# Si tan lista es Ayuso, ¿por qué no deduce con claridad la responsabilidad de las muertes en residencias?
# Toxic value:  0.8189152479171753
# ¿En qué universidad cursó usted la carrera? ¿En la misma que Pablo Casado aprobó media carrera en 6 meses o en la que Cristina Cifuentes obtuvo un master sin ir a clase ni hacer trabajos?
# Toxic value:  0.057087238878011703
# Very toxic value:  0.0015193927101790905
# Ya no pintas nada fachita. Te deseo lo mejor
# Toxic value:  0.9172511696815491
# Very toxic value:  0.022380288690328598
# Cristina cifuentes cayó por unas cremas de Olay y Rajoy por la Gurtel. La izquierda es demoledora
# Toxic value:  0.9964802861213684
# Very toxic value:  0.6285648941993713

# %%
def toxicityColors(tweet, word_to_replace):
  colors1 = ["negr", "blanc", "roj", "amarill", "morad"]
  var1 = ["a", "as", "o", "os"]
  colors2 = ["verde", "naranja", "azul"]
  plurals  = ["s", "es"]

  colors_v = {}
  for i in colors1:
    for j in var1:
      v = pipe((tweet.replace(word_to_replace, i) + j), return_all_scores=True)[0]
      colors_v.update({i+j: (v[0]['score'], v[1]['score'])})
    for i in colors2:
      v = pipe((tweet.replace(word_to_replace, i)), return_all_scores=True)[0]
      colors_v.update({i: (v[0]['score'], v[1]['score'])})
      if i != "azul":
        v = pipe((tweet.replace(word_to_replace, i+plurals[0])), return_all_scores=True)[0]
        colors_v.update({i+plurals[0]: (v[0]['score'], v[1]['score'])})
      else:
        v = pipe((tweet.replace(word_to_replace, i+plurals[1])), return_all_scores=True)[0]
        colors_v.update({i+plurals[1]: (v[0]['score'], v[1]['score'])})     
  return colors_v

# %%
frases = [
          
]

a = toxicityColors(tweet = "El vicepresidente  y sus ojos color", word_to_replace = "color")

# %%
sorted(a.items(), key=lambda x: x[1][0], reverse=True)
# Out:
# [('naranjas', (0.9760068655014038, 0.03392188996076584)),
#  ('negras', (0.9716538190841675, 0.031074611470103264)),
#  ('naranja', (0.9685986638069153, 0.0367998369038105)),
#  ('negra', (0.9666572213172913, 0.03708558902144432)),
#  ('blanco', (0.9666359424591064, 0.027665747329592705)),
#  ('negros', (0.9660590887069702, 0.02736906334757805)),
#  ('blancos', (0.9601636528968811, 0.014584367163479328)),
#  ('morada', (0.9567468166351318, 0.016520651057362556)),
#  ('negro', (0.9563860893249512, 0.029150817543268204)),
#  ('moradas', (0.9556108117103577, 0.0136176198720932)),
#  ('amarilla', (0.952187716960907, 0.018399246037006378)),
#  ('morado', (0.9418370127677917, 0.021577319130301476)),
#  ('blancas', (0.9398530721664429, 0.011923725716769695)),
#  ('amarillos', (0.9374048113822937, 0.030235301703214645)),
#  ('amarillo', (0.9287812113761902, 0.03220279887318611)),
#  ('morados', (0.9277249574661255, 0.023024406284093857)),
#  ('blanca', (0.9146777987480164, 0.015328087843954563)),
#  ('amarillas', (0.9110600352287292, 0.009685193188488483)),
#  ('roja', (0.8996136784553528, 0.02251223847270012)),
#  ('rojas', (0.8981204032897949, 0.00802377425134182)),
#  ('verde', (0.6883777976036072, 0.003589184721931815)),
#  ('verdes', (0.6569526195526123, 0.002146228915080428)),
#  ('rojos', (0.608306348323822, 0.0024682716466486454)),
#  ('rojo', (0.5535656213760376, 0.0034583990927785635)),
#  ('azules', (0.38887348771095276, 0.0017050665337592363)),
#  ('azul', (0.266353040933609, 0.002071045571938157))]
